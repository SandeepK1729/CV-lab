# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([0, 1, 2])
y = np.array([0, 3, 0])

# %%
plt.plot(x, y, marker = 'P', linestyle = 'dashed')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Line demo")
plt.show()
